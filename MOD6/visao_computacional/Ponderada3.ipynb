# %% [markdown]
# Entregável visão computacional

# %%
#instalação 

# !pip install ultralytics
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#importar bilbiotecas e definição da chave para api do roboflow

from roboflow import Roboflow
from ultralytics import YOLO
from getpass import getpass

api_key = getpass("api-key")
#a minha é "Mp3KW1QhUXLyfRp47X9e"
# Out:
# api-key··········

# %%
rf = Roboflow(api_key = api_key)
project = rf.workspace("university-bswxt").project("crack-bphdr")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.110, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to crack-2 in yolov8:: 100%|██████████| 8070/8070 [00:03<00:00, 2624.32it/s]

# %%
#agora é preciso carregar o modelo e treinar

model = YOLO('yolov8n.pt')

! yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=10 imgsz=128 plots=True
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 21.2MB/s]
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# ...

# %%
#pegando algumas imagens para ver o resultado do modelo.

from IPython.display import Image, display

display(Image(filename="runs/detect/train/val_batch0_labels.jpg"))
